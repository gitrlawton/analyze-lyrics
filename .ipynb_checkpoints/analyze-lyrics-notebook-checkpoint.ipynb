# %%
# %matplotlib inline

# Importing the necessary packages for analyzing our data.

import pandas as pd
import string
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Load dataset (a csv file containing information about all the songs) into variable 'lyrics'.

lyrics = pd.read_csv("taylor_swift_lyrics_2006-2020_all.txt")

# Inspect the first 5 rows to see what the data looks like.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line
# 0          He said the way my blue eyes shined     1
# 1  Put those Georgia stars to shame that night     2
# 2                       I said, "That's a lie"     3
# 3                  Just a boy in a Chevy truck     4
# 4         That had a tendency of gettin' stuck     5

# %%
# Print the information pertaining to the dataset (ie. number of rows/columns, column names, data type).
# 'Year of release' is noticeably absent from data set.

lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   album_name   8358 non-null   object
#  1   track_title  8358 non-null   object
#  2   track_n      8358 non-null   int64
#  3   lyric        8358 non-null   object
#  4   line         8358 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 326.6+ KB

# %%
# Print a list of all the albums in this data set.

print(lyrics.album_name.unique())
# Out:
# ['Taylor Swift' 'Fearless (Taylor’s Version)' 'Speak Now (Deluxe)'
#  'Red (Deluxe Edition)' '1989 (Deluxe)' 'reputation' 'Lover'
#  'folklore (deluxe version)' 'evermore (deluxe version)']

# %%
# Defining a function to map the name of the album to the year it was released.

def album_release(row):  
    if row['album_name'] == 'Taylor Swift':
        return '2006'
    elif row['album_name'] == 'Fearless (Taylor’s Version)':
        return '2008'
    elif row['album_name'] == 'Speak Now (Deluxe)':
        return '2010'
    elif row['album_name'] == 'Red (Deluxe Edition)':
        return '2012'
    elif row['album_name'] == '1989 (Deluxe)':
        return '2014'
    elif row['album_name'] == 'reputation':
        return '2017'
    elif row['album_name'] == 'Lover':
        return '2019'
    elif row['album_name'] == 'evermore (deluxe version)':
        return '2020'
    elif row['album_name'] == 'folklore (deluxe version)':
        return '2021'
    elif 'midnights' in row['album_name']:
        return '2022'
    
    return 'No Date'


# Applying the album release function to every row of the data set.

lyrics['album_year'] = lyrics.apply(lambda row: album_release(row), axis = 1)

# Inspect the first five rows of the data set again to make sure the corresponding years
# were successfully added.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006

# %%
# Convert lyrics to lowercase so that all occurances of the same word are considered the same, regardless of captilization.
# Save the result in a new data column called 'clean_lyric'.

lyrics['clean_lyric'] = lyrics['lyric'].str.lower()

# Remove punctuation characters.

lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace(',','')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace('"','')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("'",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace(")",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("(",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("?",'')

# Print the first five lines again to confirm correct changes.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                                    clean_lyric
# 0          he said the way my blue eyes shined
# 1  put those georgia stars to shame that night
# 2                           i said thats a lie
# 3                  just a boy in a chevy truck
# 4          that had a tendency of gettin stuck

# %%
# Create a list of "stop" words to remove.  These don't hold any value for our analysis.

stop = ['the', 'a', 'this', 'that', 'to', 'is', 'am', 'was', 'were', 'be', 'being', 'been']


# Make a list of words with `.split()`.
# Remove all the words in our list.
# Join the words back together into a string.

lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
# Create a new column to reflect if the lyrics contain midnight

lyrics['midnight'] = lyrics['clean_lyric'].str.contains('midnight')

# Print the number of times the word "midnight" occurred in the data set.

sum(lyrics['midnight'])
# Out:
# 9

# %%
# Making lists of words that are categorically similar, to see if they are referenced in the songs.

night = ['night', 'midnight', 'dawn', 'dusk', 'evening', 'late', 'dark', '1am', '2am', '3am', '4am']
day = ['day', 'morning', 'light', 'sun', 'dawn', 'noon', 'golden', 'bright']
time = ['today', 'tomorrow', 'yesterday']

# Regex string for each list to help with the searching.
night_regex = "|".join(night)
day_regex = "|".join(day)
time_regex = "|".join(time)

# Creating a new column for each of the categories of words above.
lyrics['night'] = lyrics['clean_lyric'].str.contains(night_regex)
lyrics['day'] = lyrics['clean_lyric'].str.contains(day_regex)
lyrics['time'] = lyrics['clean_lyric'].str.contains(time_regex)

# Count the number of times a word from any of those three categories appears in the lyrics.
night_count = sum(lyrics['night'])
day_count = sum(lyrics['day'])
time_count = sum(lyrics['time'])

# Print the counts.

print("night words: ", night_count)
print("day words: ", day_count)
print("time words: ", time_count)

# Inspect the first 5 rows again.
lyrics.head()
# Out:
# night words:  240
# day words:  363
# time words:  35
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                            clean_lyric  midnight  night    day   time
# 0      he said way my blue eyes shined     False  False  False  False
# 1  put those georgia stars shame night     False   True  False  False
# 2                     i said thats lie     False  False  False  False
# 3              just boy in chevy truck     False  False  False  False
# 4         had tendency of gettin stuck     False  False  False  False

# %%
# Create a new dataframe for yearly mentions, that group the occurrences of night, day, and time words by year.

yearly_mentions = lyrics.groupby('album_year').sum().reset_index()

# Correct the album names.
listOfAlbumNames = ["Taylor Swift", "Fearless", "Speak Now", "Red", "1989", "Reputation", "Lover", "Folklore", "Evermore"]

for i in range(9):
    yearly_mentions.at[i, 'album_name'] = listOfAlbumNames[i]

# Display the new dataframe's counts. 

yearly_mentions[['album_year', 'midnight', 'night', 'day', 'time']].head(10)
# Out:
#   album_year  midnight  night  day  time
# 0       2006         0     19   25     3
# 1       2008         0     42   65    20
# 2       2010         0     31   53     4
# 3       2012         1     48   53     7
# 4       2014         2     27   41     0
# 5       2017         3     25   25     0
# 6       2019         0     22   46     0
# 7       2020         2     18   38     0
# 8       2021         1      8   17     1

# %%
# Plotting the mentions of 'night' over the years.

plt.plot(yearly_mentions['album_year'], yearly_mentions['night'])
plt.title("Taylor Swift's 'night' Mentions")
plt.show()

# %%
# Sort the lyrics by the night column to find the albums with the most references to 'night'.

yearly_mentions[['album_year', 'midnight', 'night', 'day', 'time', 'album_name']].sort_values(by='night', ascending=False)
# Out:
#   album_year  midnight  night  day  time    album_name
# 3       2012         1     48   53     7           Red
# 1       2008         0     42   65    20      Fearless
# 2       2010         0     31   53     4     Speak Now
# 4       2014         2     27   41     0          1989
# 5       2017         3     25   25     0    Reputation
# 6       2019         0     22   46     0         Lover
# 0       2006         0     19   25     3  Taylor Swift
# 7       2020         2     18   38     0      Folklore
# 8       2021         1      8   17     1      Evermore

# %%
# Sort the lyrics by the day column to find the albums with the most references to 'day'.

yearly_mentions[['album_year', 'midnight', 'night', 'day', 'time', 'album_name']].sort_values(by='day', ascending=False)
# Out:
#   album_year  midnight  night  day  time    album_name
# 1       2008         0     42   65    20      Fearless
# 2       2010         0     31   53     4     Speak Now
# 3       2012         1     48   53     7           Red
# 6       2019         0     22   46     0         Lover
# 4       2014         2     27   41     0          1989
# 7       2020         2     18   38     0      Folklore
# 0       2006         0     19   25     3  Taylor Swift
# 5       2017         3     25   25     0    Reputation
# 8       2021         1      8   17     1      Evermore

# %%
# Plotting the number of mentions of 'night' and 'day' through the years on the 
# same graph to help compare the two above tables.

plt.plot(yearly_mentions['album_year'], yearly_mentions['night'], label = 'night')
plt.plot(yearly_mentions['album_year'], yearly_mentions['day'], label = 'day')
plt.title("Day vs. Night mentions")

plt.legend()
plt.show()

# %%
# Testing to see if there's any noticeable trends in the mentions
# throughout the course of the songs.

# Creating a new column called "position" and assigning each line in the song a hash code.
lyrics['position'] = lyrics['track_n'] + (lyrics['line']/1000)

# Creating a new dataframe grouped by position and adding up the number of mentions by their hash code.
positional_mentions = lyrics.groupby('position').sum().reset_index()

# Setting the size of the plot.
fig = plt.gcf()
fig.set_size_inches(25, 10)

# Creating a two-line plot with labels and lines to show frequency of 'night' and frequency of 'day'
# mentions.
plt.plot(positional_mentions['position'], positional_mentions['night'], label = 'night')
plt.plot(positional_mentions['position'], positional_mentions['day'], label = 'day')
plt.legend()
plt.title("Day vs. Night mentions by Album Position")

plt.show()

# %%
# Tokenize the words in our clean_lyric column by splitting them around space characters.

lyrics['lyrics_token'] = lyrics['clean_lyric'].str.split(' ')

# Inspect the first five lines so we can see what the new lyrics_token column looks like.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                            clean_lyric  midnight  night    day   time  \
# 0      he said way my blue eyes shined     False  False  False  False
# 1  put those georgia stars shame night     False   True  False  False
# 2                     i said thats lie     False  False  False  False
# 3              just boy in chevy truck     False  False  False  False
# 4         had tendency of gettin stuck     False  False  False  False
#
#    position                                lyrics_token
# 0     1.001     [he, said, way, my, blue, eyes, shined]
# 1     1.002  [put, those, georgia, stars, shame, night]
# 2     1.003                       [i, said, thats, lie]
# 3     1.004               [just, boy, in, chevy, truck]
# 4     1.005          [had, tendency, of, gettin, stuck]

# %%
# Determine what the most frequently used words are by first creating a list of all the words
# in the lyrics_token column.
word_list = [word for list_ in lyrics['lyrics_token'] for word in list_]

# Utilize the counter function to count the number of times each word appears.
word_frequency = collections.Counter(word_list)

# Sort the word frequencies to determine the most common words used.
word_frequency = sorted(word_frequency.items(), key=lambda x: x[1], reverse=True)

# Display the word frequencies.
word_frequency
# Out:
# [('you', 2832),
#  ('i', 2633),
#  ('and', 1712),
#  ('me', 1051),
#  ('it', 930),
#  ('in', 887),
#  ('my', 816),
#  ('your', 623),
#  ('of', 592),
#  ('but', 540),
#  ('all', 531),
#  ('we', 498),
#  ('im', 496),
#  ('like', 488),
#  ('on', 467),
#  ('know', 456),
#  ('so', 422),
#  ('oh', 403),
#  ('when', 392),
#  ('dont', 391),
#  ('its', 372),
#  ('never', 353),
#  ('just', 339),
#  ('youre', 316),
#  ('for', 306),
#  ('now', 305),
#  ('with', 302),
#  ('love', 295),
#  ('what', 284),
#  ('up', 272),
#  ('out', 270),
#  ('back', 267),
#  ('time', 261),
#  ('at', 249),
#  ('if', 245),
#  ('cause', 245),
#  ('are', 225),
#  ('no', 211),
#  ('one', 201),
#  ('got', 201),
#  ('see', 199),
#  ('say', 198),
#  ('do', 195),
#  ('think', 192),
#  ('baby', 188),
#  ('down', 181),
#  ('go', 180),
#  ('want', 180),
#  ('they', 173),
#  ('come', 172),
#  ('could', 167),
#  ('can', 164),
#  ('there', 162),
#  ('not', 162),
#  ('wanna', 161),
#  ('right', 155),
#  ('cant', 153),
#  ('said', 146),
#  ('have', 146),
#  ('yeah', 145),
#  ('he', 142),
#  ('ill', 141),
#  ('ever', 140),
#  ('would', 140),
#  ('had', 134),
#  ('thats', 133),
#  ('look', 133),
#  ('get', 127),
#  ('how', 122),
#  ('here', 121),
#  ('stay', 120),
#  ('take', 119),
#  ('way', 116),
#  ('ive', 116),
#  ('tell', 115),
#  ('night', 114),
#  ('still', 113),
#  ('id', 112),
#  ('gonna', 110),
#  ('about', 110),
#  ('home', 110),
#  ('as', 108),
#  ('off', 104),
#  ('did', 102),
#  ('made', 102),
#  ('good', 102),
#  ('ooh', 101),
#  ('why', 100),
#  ('from', 98),
#  ('too', 98),
#  ('oh-oh', 97),
#  ('feel', 96),
#  ('around', 95),
#  ('bad', 93),
#  ('everything', 93),
#  ('then', 90),
#  ('better', 90),
#  ('things', 90),
#  ('our', 90),
#  ('away', 88),
#  ('didnt', 87),
#  ('only', 86),
#  ('call', 85),
#  ('girl', 84),
#  ('wish', 84),
#  ('again', 84),
#  ('through', 83),
#  ('new', 83),
#  ('eyes', 82),
#  ('long', 81),
#  ('let', 81),
#  ('shake', 81),
#  ('every', 79),
#  ('knew', 79),
#  ('him', 78),
#  ('who', 76),
#  ('red', 76),
#  ('first', 75),
#  ('ah', 75),
#  ('will', 74),
#  ('name', 73),
#  ('eh', 73),
#  ('last', 72),
#  ('youll', 71),
#  ('well', 71),
#  ('yet', 71),
#  ('little', 70),
#  ('thing', 70),
#  ('by', 70),
#  ('make', 70),
#  ('she', 69),
#  ('nothing', 68),
#  ('forever', 67),
#  ('where', 66),
#  ('hes', 65),
#  ('life', 64),
#  ('best', 63),
#  ('keep', 62),
#  ('break', 62),
#  ('us', 62),
#  ('heart', 61),
#  ('face', 61),
#  ('or', 61),
#  ('leave', 61),
#  ('day', 60),
#  ('lights', 60),
#  ('even', 59),
#  ('gone', 58),
#  ('alone', 58),
#  ('mind', 58),
#  ('always', 58),
#  ('need', 57),
#  ('remember', 56),
#  ('his', 55),
#  ('into', 55),
#  ('waiting', 55),
#  ('smile', 54),
#  ('should', 54),
#  ('something', 54),
#  ('man', 54),
#  ('theres', 52),
#  ('beautiful', 52),
#  ('hey', 52),
#  ('thought', 52),
#  ('before', 52),
#  ('over', 52),
#  ('car', 51),
#  ('isnt', 51),
#  ('dancing', 51),
#  ('knows', 50),
#  ('some', 49),
#  ('whoa', 49),
#  ('find', 48),
#  ('hope', 48),
#  ('friends', 48),
#  ('aint', 48),
#  ('an', 48),
#  ('hands', 48),
#  ('mad', 48),
#  ('mine', 47),
#  ('wont', 47),
#  ('hold', 47),
#  ('head', 46),
#  ('shes', 45),
#  ('fall', 45),
#  ('wrong', 45),
#  ('walk', 45),
#  ('end', 45),
#  ('door', 45),
#  ('lost', 45),
#  ('put', 44),
#  ('hate', 44),
#  ('coming', 44),
#  ('her', 44),
#  ('feeling', 44),
#  ('run', 44),
#  ('hand', 44),
#  ('mean', 44),
#  ('left', 43),
#  ('once', 43),
#  ('sorry', 42),
#  ('clear', 42),
#  ('place', 41),
#  ('light', 41),
#  ('miss', 41),
#  ('much', 41),
#  ('old', 40),
#  ('trying', 40),
#  ('them', 40),
#  ('talk', 40),
#  ('youve', 40),
#  ('daylight', 40),
#  ('saw', 39),
#  ('than', 39),
#  ('enough', 39),
#  ('room', 39),
#  ('took', 39),
#  ('dress', 38),
#  ('watch', 38),
#  ('dreams', 38),
#  ('hear', 38),
#  ('meet', 38),
#  ('everybody', 38),
#  ('follow', 38),
#  ('york', 38),
#  ('woods', 38),
#  ('really', 37),
#  ('town', 37),
#  ('whole', 37),
#  ('play', 37),
#  ('dark', 37),
#  ('live', 36),
#  ('rain', 36),
#  ('world', 36),
#  ('met', 36),
#  ('these', 36),
#  ('street', 35),
#  ('give', 35),
#  ('known', 35),
#  ('their', 35),
#  ('kiss', 35),
#  ('blue', 34),
#  ('together', 34),
#  ('other', 34),
#  ('people', 34),
#  ('ha', 34),
#  ('nice', 33),
#  ('shouldve', 33),
#  ('asking', 33),
#  ('gave', 33),
#  ('forget', 33),
#  ('big', 33),
#  ('song', 32),
#  ('more', 32),
#  ('used', 32),
#  ('has', 32),
#  ('welcome', 32),
#  ('|', 32),
#  ('darling', 32),
#  ('trouble', 32),
#  ('youd', 31),
#  ('fight', 31),
#  ('wanted', 31),
#  ('anything', 31),
#  ('same', 31),
#  ('phone', 31),
#  ('lose', 31),
#  ('game', 31),
#  ('those', 30),
#  ('another', 30),
#  ('else', 30),
#  ('loved', 30),
#  ('wait', 30),
#  ('getting', 30),
#  ('meaning', 30),
#  ('hard', 29),
#  ('turn', 29),
#  ('today', 29),
#  ('myself', 29),
#  ('help', 29),
#  ('please', 29),
#  ('yes', 29),
#  ('silence', 29),
#  ('touch', 29),
#  ('official', 29),
#  ('lyrics', 29),
#  ('&', 29),
#  ('verified', 29),
#  ('heard', 28),
#  ('goes', 28),
#  ('times', 28),
#  ('side', 28),
#  ('mr.', 28),
#  ('believe', 27),
#  ('drive', 27),
#  ('show', 27),
#  ('fake', 27),
#  ('without', 27),
#  ('breathe', 27),
#  ('fly', 27),
#  ('went', 27),
#  ('looking', 27),
#  ('late', 27),
#  ('true', 27),
#  ('found', 27),
#  ('soon', 27),
#  ('you’re', 27),
#  ('soul', 27),
#  ('body', 27),
#  ('honey', 26),
#  ('try', 26),
#  ('high', 26),
#  ('might', 26),
#  ('change', 26),
#  ('til', 26),
#  ('standing', 26),
#  ('weve', 26),
#  ('bye', 26),
#  ('joeboy', 26),
#  ('sip', 26),
#  ('alcohol', 26),
#  ('someday', 25),
#  ('fine', 25),
#  ('story', 25),
#  ('places', 25),
#  ('save', 25),
#  ('came', 25),
#  ('friend', 25),
#  ('rains', 25),
#  ('grow', 25),
#  ('boy', 24),
#  ('far', 24),
#  ('front', 24),
#  ('wed', 24),
#  ('years', 24),
#  ('after', 24),
#  ('seen', 24),
#  ('dead', 24),
#  ('fun', 24),
#  ('crazy', 23),
#  ('wishing', 23),
#  ('many', 23),
#  ('shine', 23),
#  ('ground', 23),
#  ('anymore', 23),
#  ('dance', 23),
#  ('makes', 23),
#  ('happy', 23),
#  ('couldnt', 23),
#  ('eye', 23),
#  ('jump', 23),
#  ('dream', 23),
#  ('alright', 23),
#  ('summer', 22),
#  ('since', 22),
#  ('guess', 22),
#  ('sometimes', 22),
#  ('stop', 22),
#  ('cool', 22),
#  ('sad', 22),
#  ('okay', 22),
#  ('must', 22),
#  ('lips', 22),
#  ('starlight', 22),
#  ('getaway', 22),
#  ('picture', 21),
#  ('looks', 21),
#  ('very', 21),
#  ('thinking', 21),
#  ('tied', 21),
#  ('window', 21),
#  ('past', 21),
#  ('both', 21),
#  ('young', 21),
#  ('wouldve', 21),
#  ('burning', 21),
#  ('walking', 20),
#  ('words', 20),
#  ('nobody', 20),
#  ('died', 20),
#  ('moment', 20),
#  ('house', 20),
#  ('morning', 20),
#  ('walked', 20),
#  ('somebody', 20),
#  ('days', 20),
#  ('stand', 20),
#  ('games', 20),
#  ('em', 20),
#  ('pain', 20),
#  ('gotta', 20),
#  ('perfectly', 19),
#  ('kind', 19),
#  ('maybe', 19),
#  ('road', 19),
#  ('told', 19),
#  ('bout', 19),
#  ('hair', 19),
#  ('middle', 19),
#  ('close', 19),
#  ('fairytale', 19),
#  ('clean', 19),
#  ('babe', 19),
#  ('showed', 19),
#  ('blood', 19),
#  ('wonderland', 19),
#  ('missing', 18),
#  ('finally', 18),
#  ('tonight', 18),
#  ('ask', 18),
#  ('cold', 18),
#  ('loving', 18),
#  ('girls', 18),
#  ('gets', 18),
#  ('real', 18),
#  ('making', 18),
#  ('deep', 18),
#  ('laughing', 18),
#  ('single', 18),
#  ('yours', 18),
#  ('stars', 17),
#  ('shame', 17),
#  ('god', 17),
#  ('read', 17),
#  ('perfect', 17),
#  ('bet', 17),
#  ('lucky', 17),
#  ('stood', 17),
#  ('pretty', 17),
#  ('sky', 17),
#  ('two', 17),
#  ('along', 17),
#  ('while', 17),
#  ('magic', 17),
#  ('easy', 17),
#  ('cut', 17),
#  ('because', 17),
#  ('fell', 17),
#  ('felt', 17),
#  ('string', 17),
#  ('begin', 17),
#  ('delicate', 17),
#  ('says', 16),
#  ('reason', 16),
#  ('feels', 16),
#  ('own', 16),
#  ('doesnt', 16),
#  ('goodbye', 16),
#  ('someone', 16),
#  ('la', 16),
#  ('begging', 16),
#  ('beat', 16),
#  ('wasnt', 16),
#  ('almost', 16),
#  ('open', 16),
#  ('caught', 16),
#  ('tired', 16),
#  ('oh-oh-oh', 16),
#  ('line', 16),
#  ('held', 16),
#  ('city', 16),
#  ('free', 16),
#  ('alive', 16),
#  ('gorgeous', 16),
#  ('cornelia', 16),
#  ('favorite', 15),
#  ('happiness', 15),
#  ('tears', 15),
#  ('laugh', 15),
#  ('losing', 15),
#  ('looked', 15),
#  ('next', 15),
#  ('party', 15),
#  ('white', 15),
#  ('belong', 15),
#  ('simple', 15),
#  ('hurt', 15),
#  ('sick', 15),
#  ('heres', 15),
#  ('screaming', 15),
#  ('called', 15),
#  ('sure', 15),
#  ('under', 15),
#  ('sun', 15),
#  ('die', 15),
#  ('running', 15),
#  ('list', 15),
#  ('trust', 15),
#  ('i’ll', 15),
#  ('don’t', 15),
#  ('works', 15),
#  ('worse', 15),
#  ('fancy', 15),
#  ('plans', 15),
#  ('bless', 15),
#  ('black', 14),
#  ('bed', 14),
#  ('stupid', 14),
#  ('whos', 14),
#  ('saying', 14),
#  ('whats', 14),
#  ('ending', 14),
#  ('anywhere', 14),
#  ('lot', 14),
#  ('couldve', 14),
#  ('does', 14),
#  ('taking', 14),
#  ('sing', 14),
#  ('crying', 14),
#  ('worth', 14),
#  ('whenever', 14),
#  ('most', 14),
#  ('comes', 14),
#  ('doing', 14),
#  ('doin', 14),
#  ('each', 14),
#  ('bright', 14),
#  ('worst', 14),
#  ('memories', 14),
#  ('treacherous', 14),
#  ('sitting', 13),
#  ('burn', 13),
#  ('anyone', 13),
#  ('work', 13),
#  ('outside', 13),
#  ('cry', 13),
#  ('golden', 13),
#  ('undone', 13),
#  ('breath', 13),
#  ('turned', 13),
#  ('behind', 13),
#  ('apart', 13),
#  ('signs', 13),
#  ('round', 13),
#  ('wondering', 13),
#  ('wake', 13),
#  ('watched', 13),
#  ('speak', 13),
#  ('school', 13),
#  ('learned', 13),
#  ('rest', 13),
#  ('pretend', 13),
#  ('december', 13),
#  ('nights', 13),
#  ('hit', 13),
#  ('drunk', 13),
#  ('moved', 13),
#  ('theyll', 13),
#  ('22', 13),
#  ('problems', 13),
#  ('loves', 13),
#  ('bought', 13),
#  ('ooh-ooh-ooh-ooh', 13),
#  ('takes', 12),
#  ('heartbreak', 12),
#  ('funny', 12),
#  ('sleep', 12),
#  ('though', 12),
#  ('walls', 12),
#  ('paint', 12),
#  ('gray', 12),
#  ('wouldnt', 12),
#  ('until', 12),
#  ('fire', 12),
#  ('boys', 12),
#  ('fifteen', 12),
#  ('sit', 12),
#  ('theyre', 12),
#  ('changed', 12),
#  ('talking', 12),
#  ('catch', 12),
#  ('step', 12),
#  ('fighting', 12),
#  ('rush', 12),
#  ('wild', 12),
#  ('low', 12),
#  ('gold', 12),
#  ('win', 12),
#  ('million', 12),
#  ('burned', 12),
#  ('cruel', 12),
#  ('floor', 12),
#  ('fast', 12),
#  ('busy', 12),
#  ('quite', 12),
#  ('any', 12),
#  ('reputation', 12),
#  ('hey!', 12),
#  ('usin', 12),
#  ('ooh-ah', 12),
#  ('going', 11),
#  ('havent', 11),
#  ('wonder', 11),
#  ('ready', 11),
#  ('damn', 11),
#  ('seems', 11),
#  ('lets', 11),
#  ('daydream', 11),
#  ('word', 11),
#  ('slow', 11),
#  ('tryna', 11),
#  ('hide', 11),
#  ('invisible', 11),
#  ('inside', 11),
#  ('ends', 11),
#  ('flashback', 11),
#  ('starts', 11),
#  ('air', 11),
#  ('pulled', 11),
#  ('write', 11),
#  ('feet', 11),
#  ('killing', 11),
#  ('insane', 11),
#  ('scared', 11),
#  ('throw', 11),
#  ('hang', 11),
#  ('broke', 11),
#  ('water', 11),
#  ('sparks', 11),
#  ('green', 11),
#  ('passed', 11),
#  ('blame', 11),
#  ('promise', 11),
#  ('paper', 11),
#  ('marvelous', 11),
#  ('ya', 11),
#  ('style', 11),
#  ('sign', 11),
#  ('drug', 11),
#  ('uh', 11),
#  ('woman', 11),
#  ('three', 10),
#  ('lying', 10),
#  ('taken', 10),
#  ('strong', 10),
#  ('mess', 10),
#  ('cried', 10),
#  ('giving', 10),
#  ('falling', 10),
#  ('brave', 10),
#  ('hello', 10),
#  ('brought', 10),
#  ('figured', 10),
#  ('hearts', 10),
#  ('cuts', 10),
#  ('heaven', 10),
#  ('everyone', 10),
#  ('arms', 10),
#  ('turns', 10),
#  ('blind', 10),
#  ('nobodys', 10),
#  ('started', 10),
#  ('spinning', 10),
#  ('months', 10),
#  ('slope', 10),
#  ('scene', 10),
#  ('lord', 10),
#  ('lover', 10),
#  ('wildest', 10),
#  ('a-team', 10),
#  ('whys', 10),
#  ('american', 10),
#  ('wine', 10),
#  ('forgot', 10),
#  ('worship', 10),
#  ('prove', 10),
#  ('closure', 10),
#  ('shined', 9),
#  ('truck', 9),
#  ('yourself', 9),
#  ('drew', 9),
#  ('less', 9),
#  ('pictures', 9),
#  ('chance', 9),
#  ('stayed', 9),
#  ('half', 9),
#  ('fearless', 9),
#  ('garden', 9),
#  ('afraid', 9),
#  ('faith', 9),
#  ('mm-mm', 9),
#  ('lead', 9),
#  ('small', 9),
#  ('short', 9),
#  ('movie', 9),
#  ('2', 9),
#  ('heartbeat', 9),
#  ('breaking', 9),
#  ('warning', 9),
#  ('drop', 9),
#  ('move', 9),
#  ('threw', 9),
#  ('mistakes', 9),
#  ('pouring', 9),
#  ('swear', 9),
#  ('understand', 9),
#  ('dressed', 9),
#  ('death', 9),
#  ('peace', 9),
#  ('shaking', 9),
#  ('bar', 9),
#  ('loud', 9),
#  ('page', 9),
#  ('fate', 9),
#  ('broken', 9),
#  ('grace', 9),
#  ('uh-uh', 9),
#  ('london', 9),
#  ('ah-ah', 9),
#  ('rumors', 9),
#  ('covered', 9),
#  ('calm', 9),
#  ('shit', 9),
#  ('ra-di-di-di-di-di-di-di-di-di-da-da', 9),
#  ('champagne', 9),
#  ('rings', 9),
#  ('evermore', 9),
#  ('jeans', 8),
#  ('letter', 8),
#  ('strike', 8),
#  ('guitar', 8),
#  ('keeps', 8),
#  ('great', 8),
#  ('tried', 8),
#  ('part', 8),
#  ('waters', 8),
#  ('leads', 8),
#  ('instead', 8),
#  ('spot', 8),
#  ('living', 8),
#  ('fears', 8),
#  ('stare', 8),
#  ('scar', 8),
#  ('singing', 8),
#  ('storm', 8),
#  ('somewhere', 8),
#  ('quiet', 8),
#  ('mmm', 8),
#  ('wear', 8),
#  ('dreaming', 8),
#  ('heels', 8),
#  ('playing', 8),
#  ('bring', 8),
#  ('innocent', 8),
#  ('space', 8),
#  ('bedroom', 8),
#  ('it’s', 8),
#  ('lives', 8),
#  ('wind', 8),
#  ('scream', 8),
#  ('sweet', 8),
#  ('such', 8),
#  ('telling', 8),
#  ('reckless', 8),
#  ('haunt', 8),
#  ('sleeping', 8),
#  ('queen', 8),
#  ('flew', 8),
#  ('ones', 8),
#  ('care', 8),
#  ('flames', 8),
#  ('choice', 8),
#  ('thousand', 8),
#  ('tall', 8),
#  ('flying', 8),
#  ('solve', 8),
#  ('bone', 8),
#  ('hell', 8),
#  ('pieces', 8),
#  ('cheeks', 8),
#  ('kid', 8),
#  ('ooh-ooh-ooh-ooh-ooh', 8),
#  ('oh-ho', 8),
#  ('warm', 8),
#  ('train', 8),
#  ('money', 8),
#  ('rose', 8),
#  ('king', 8),
#  ('mmm-mmm', 8),
#  ('oh!', 8),
#  ('ha-ah', 8),
#  ('kill', 8),
#  ('film', 8),
#  ('wreck', 8),
#  ('dorothea', 8),
#  ('lie', 7),
#  ('faded', 7),
#  ('wasted', 7),
#  ('case', 7),
#  ('talks', 7),
#  ('tight', 7),
#  ('wearing', 7),
#  ('start', 7),
#  ('counting', 7),
#  ('few', 7),
#  ('lonely', 7),
#  ('hoping', 7),
#  ('pay', 7),
#  ('songs', 7),
#  ('conversation', 7),
#  ('twice', 7),
#  ('shouldnt', 7),
#  ('forgiveness', 7),
#  ('honestly', 7),
#  ('joke', 7),
#  ('ran', 7),
#  ('believed', 7),
#  ('ridin', 7),
#  ('seat', 7),
#  ('shell', 7),
#  ('wall', 7),
#  ('realized', 7),
#  ('driving', 7),
#  ('team', 7),
#  ('marry', 7),
#  ('prince', 7),
#  ('ring', 7),
#  ('pick', 7),
#  ('mmm-mm', 7),
#  ('rocks', 7),
#  ('holding', 7),
#  ('leaving', 7),
#  ('shoulda', 7),
#  ('knees', 7),
#  ('someones', 7),
#  ('cursing', 7),
#  ('hallelujah', 7),
#  ('faster', 7),
#  ('battle', 7),
#  ('sound', 7),
#  ('spelling', 7),
#  ('rules', 7),
#  ('stairs', 7),
#  ('lived', 7),
#  ('freedom', 7),
#  ('hows', 7),
#  ('above', 7),
#  ('shining', 7),
#  ('i-i-i', 7),
#  ('truth', 7),
#  ('clothes', 7),
#  ('skin', 7),
#  ('whisper', 7),
#  ('dear', 7),
#  ('dying', 7),
#  ('older', 7),
#  ('colder', 7),
#  ('spend', 7),
#  ('actress', 7),
#  ('roll', 7),
#  ('brand', 7),
#  ('haunted', 7),
#  ('kingdom', 7),
#  ('ours', 7),
#  ('somehow', 7),
#  ('superman', 7),
#  ('hurts', 7),
#  ('headlights', 7),
#  ('drowning', 7),
#  ('asked', 7),
#  ('they’ll', 7),
#  ('lipstick', 7),
#  ('players', 7),
#  ('twenty', 7),
#  ('palm', 7),
#  ('whyd', 7),
#  ('shiny', 7),
#  ('glass', 7),
#  ('huh', 7),
#  ('me-e-e', 7),
#  ('tim', 6),
#  ('mcgraw', 6),
#  ('standin', 6),
#  ('radio', 6),
#  ('teardrops', 6),
#  ('given', 6),
#  ('use', 6),
#  ('shade', 6),
#  ('scars', 6),
#  ('view', 6),
#  ('smiles', 6),
#  ('least', 6),
#  ('strange', 6),
#  ('fore', 6),
#  ('wide', 6),
#  ('nothin', 6),
#  ('hallway', 6),
#  ('lovin', 6),
#  ('secrets', 6),
#  ('la-la-la', 6),
#  ('crowd', 6),
#  ('romeo', 6),
#  ('near', 6),
#  ('reasons', 6),
#  ('forth', 6),
#  ('itll', 6),
#  ('2am', 6),
#  ('happened', 6),
#  ('second', 6),
#  ('hasnt', 6),
#  ('trees', 6),
#  ('names', 6),
#  ('ride', 6),
#  ('’cause', 6),
#  ('brighter', 6),
#  ('dim', 6),
#  ('comin', 6),
#  ('starin', 6),
#  ('lies', 6),
#  ('amount', 6),
#  ('casually', 6),
#  ('different', 6),
#  ('gate', 6),
#  ('daughter', 6),
#  ('family', 6),
#  ('pushed', 6),
#  ('grown', 6),
#  ('cross', 6),
#  ('enchanted', 6),
#  ('smoke', 6),
#  ('saint', 6),
#  ('colors', 6),
#  ('forgetting', 6),
#  ('impossible', 6),
#  ('midnight', 6),
#  ('tragic', 6),
#  ('lock', 6),
#  ('motion', 6),
#  ('seem', 6),
#  ('i’d', 6),
#  ('weekend', 6),
#  ('ex-lovers', 6),
#  ('skies', 6),
#  ('crashing', 6),
#  ('color', 6),
#  ('windows', 6),
#  ('hung', 6),
#  ('done', 6),
#  ('frames', 6),
#  ('sight', 6),
#  ('castle', 6),
#  ('romantics', 6),
#  ('da-da', 6),
#  ('chill', 6),
#  ('crime', 6),
#  ('me—', 6),
#  ('goes…', 6),
#  ('secret', 6),
#  ('frozen', 6),
#  ('shape', 6),
#  ('babys', 6),
#  ('existed', 6),
#  ('wants', 6),
#  ('1', 6),
#  ('hometown', 6),
#  ('likes', 6),
#  ('false', 6),
#  ('waves', 6),
#  ('august', 6),
#  ('goddamn', 6),
#  ('stone', 6),
#  ('woke', 5),
#  ('moon', 5),
#  ('spotlight', 5),
#  ('werent', 5),
#  ('beneath', 5),
#  ('state', 5),
#  ('realize', 5),
#  ('match', 5),
#  ('revenge', 5),
#  ('daddys', 5),
#  ('flawless', 5),
#  ('rainy', 5),
#  ('between', 5),
#  ('pocket', 5),
#  ('whispers', 5),
#  ('corner', 5),
#  ('na', 5),
#  ('flowers', 5),
#  ('yesterday', 5),
#  ('bigger', 5),
#  ('kids', 5),
#  ('slamming', 5),
#  ('porch', 5),
#  ('note', 5),
#  ('listen', 5),
#  ('matter', 5),
#  ('sense', 5),
#  ('drag', 5),
#  ('dancin', 5),
#  ('swore', 5),
#  ('supposed', 5),
#  ('princess', 5),
#  ('stephen', 5),
#  ('tossing', 5),
#  ('angel', 5),
#  ('tuesday', 5),
#  ('music', 5),
#  ('understands', 5),
#  ('streets', 5),
#  ...]

# %%
# Adding an NLTK package for our sentiment analyzer.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rlawt\AppData\Roaming\nltk_data...
# True

# %%
# Testing out the sentiment analyzer.
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love Taylor Swift!")

# Compound is the normalized sum of neutral and positive.  It takes intesity into account.
# Out:
# {'neg': 0.0, 'neu': 0.137, 'pos': 0.863, 'compound': 0.7424}

# %%
# This particular analyzer takes in an entire string and applies its own tokenization process to it (per its documentation.)  
# Therefore, I don't want to use already tokenized lyrics.

# Apply sentiment analyzer's polarity_scores() function to everything in the clean_lyric column.
# Returns a dictionary to be stored in our new column containing values for 'negative', 'neutral', 'positive'.
lyrics['polarity'] = lyrics['clean_lyric'].apply(lambda x: sia.polarity_scores(x))

# Inspect the first five rows of the dataframe.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                            clean_lyric  midnight  night    day   time  \
# 0      he said way my blue eyes shined     False  False  False  False
# 1  put those georgia stars shame night     False   True  False  False
# 2                     i said thats lie     False  False  False  False
# 3              just boy in chevy truck     False  False  False  False
# 4         had tendency of gettin stuck     False  False  False  False
#
#    position                                lyrics_token  \
# 0     1.001     [he, said, way, my, blue, eyes, shined]
# 1     1.002  [put, those, georgia, stars, shame, night]
# 2     1.003                       [i, said, thats, lie]
# 3     1.004               [just, boy, in, chevy, truck]
# 4     1.005          [had, tendency, of, gettin, stuck]
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'comp...

# %%
# Transform the column with the polarity dictionaries into new, separate columns  for each value using pandas series.
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)

# Remove the now unnecessary polarity column from the dataframe.
lyrics.drop('polarity', axis=1)
# Out:
#                      album_name       track_title  track_n  \
# 0                  Taylor Swift        Tim McGraw        1
# 1                  Taylor Swift        Tim McGraw        1
# 2                  Taylor Swift        Tim McGraw        1
# 3                  Taylor Swift        Tim McGraw        1
# 4                  Taylor Swift        Tim McGraw        1
# ...                         ...               ...      ...
# 8353  evermore (deluxe version)  ​it’s time to go       17
# 8354  evermore (deluxe version)  ​it’s time to go       17
# 8355  evermore (deluxe version)  ​it’s time to go       17
# 8356  evermore (deluxe version)  ​it’s time to go       17
# 8357  evermore (deluxe version)  ​it’s time to go       17
#
#                                             lyric  line album_year  \
# 0             He said the way my blue eyes shined     1       2006
# 1     Put those Georgia stars to shame that night     2       2006
# 2                          I said, "That's a lie"     3       2006
# 3                     Just a boy in a Chevy truck     4       2006
# 4            That had a tendency of gettin' stuck     5       2006
# ...                                           ...   ...        ...
# 8353       You know, you know, you know, you know    50       2020
# 8354                         When it's time to go    51       2020
# 8355                               So then you go    52       2020
# 8356                                  Then you go    53       2020
# 8357                                  You just go    54       2020
#
#                               clean_lyric  midnight  night    day   time  \
# 0         he said way my blue eyes shined     False  False  False  False
# 1     put those georgia stars shame night     False   True  False  False
# 2                        i said thats lie     False  False  False  False
# 3                 just boy in chevy truck     False  False  False  False
# 4            had tendency of gettin stuck     False  False  False  False
# ...                                   ...       ...    ...    ...    ...
# 8353  you know you know you know you know     False  False  False  False
# 8354                     when its time go     False  False  False  False
# 8355                       so then you go     False  False  False  False
# 8356                          then you go     False  False  False  False
# 8357                          you just go     False  False  False  False
#
#       position                                  lyrics_token    neg    neu  \
# 0        1.001       [he, said, way, my, blue, eyes, shined]  0.000  1.000
# 1        1.002    [put, those, georgia, stars, shame, night]  0.383  0.617
# 2        1.003                         [i, said, thats, lie]  0.000  1.000
# 3        1.004                 [just, boy, in, chevy, truck]  0.000  1.000
# 4        1.005            [had, tendency, of, gettin, stuck]  0.333  0.667
# ...        ...                                           ...    ...    ...
# 8353    17.050  [you, know, you, know, you, know, you, know]  0.000  1.000
# 8354    17.051                         [when, its, time, go]  0.000  1.000
# 8355    17.052                           [so, then, you, go]  0.000  1.000
# 8356    17.053                               [then, you, go]  0.000  1.000
# 8357    17.054                               [you, just, go]  0.000  1.000
#
#       pos  compound
# 0     0.0    0.0000
# 1     0.0   -0.4767
# 2     0.0    0.0000
# 3     0.0    0.0000
# 4     0.0   -0.2500
# ...   ...       ...
# 8353  0.0    0.0000
# 8354  0.0    0.0000
# 8355  0.0    0.0000
# 8356  0.0    0.0000
# 8357  0.0    0.0000
#
# [8358 rows x 17 columns]
