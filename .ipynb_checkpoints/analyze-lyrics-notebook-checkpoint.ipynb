# %% [markdown]
#  # Text (Lyrics) Analysis with Python

# %%
# Importing the necessary libraries for analyzing our data.

# %matplotlib inline

import pandas as pd
import string
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Load dataset (a csv file containing information about all the songs) into variable 'lyrics'.

lyrics = pd.read_csv("lyrics_all.txt")

# Inspect the first 5 rows to see what the dataframe looks like.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line
# 0          He said the way my blue eyes shined     1
# 1  Put those Georgia stars to shame that night     2
# 2                       I said, "That's a lie"     3
# 3                  Just a boy in a Chevy truck     4
# 4         That had a tendency of gettin' stuck     5

# %%
# Print the information pertaining to the dataset (ie. number of columns, column names, data types).
# 'release year' is a column name we'd like to have, but isn't present in the original dataset.

lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7597 entries, 0 to 7596
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   album_name   7597 non-null   object
#  1   track_title  7597 non-null   object
#  2   track_n      7597 non-null   int64
#  3   lyric        7597 non-null   object
#  4   line         7597 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 296.9+ KB

# %% [markdown]
# # Add a column to hold each album's year of release

# %%
# Print a list of all the album names in this dataset. We'll use these to help construct our album_year column.

print(lyrics.album_name.unique())
# Out:
# ['Taylor Swift' 'Fearless (Taylor’s Version)' 'Speak Now (Deluxe)'
#  'Red (Deluxe Edition)' '1989 (Deluxe)' 'reputation' 'Lover'
#  'folklore (deluxe version)' 'evermore (deluxe version)' 'Midnights']

# %%
# Defining a function to map the name of the album to the year it was released.

def album_release(row):  
    if row['album_name'] == 'Taylor Swift':
        return '2006'
    elif row['album_name'] == 'Fearless (Taylor’s Version)':
        return '2008'
    elif row['album_name'] == 'Speak Now (Deluxe)':
        return '2010'
    elif row['album_name'] == 'Red (Deluxe Edition)':
        return '2012'
    elif row['album_name'] == '1989 (Deluxe)':
        return '2014'
    elif row['album_name'] == 'reputation':
        return '2017'
    elif row['album_name'] == 'Lover':
        return '2019'
    elif row['album_name'] == 'folklore (deluxe version)':
        return '2020'
    elif row['album_name'] == 'evermore (deluxe version)':
        return '2021'
    elif 'Midnights' in row['album_name']:
        return '2022'
    
    return 'No Date'


# Applying the album release function to every row of the data set.

lyrics['album_year'] = lyrics.apply(album_release, axis = 1)

# Inspect the first five rows of the data set again to make sure the corresponding years
# were successfully added.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006

# %% [markdown]
# # Clean the lyrics

# %%
# Convert lyrics to lowercase so that all occurances of the same word are considered the same, regardless of captilization.
# Save the result in a new data column called 'clean_lyric'.

lyrics['clean_lyric'] = lyrics['lyric'].str.lower()

# Remove punctuation characters.

lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace(',','')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace('"','')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("'",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace(")",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("(",'')
lyrics['clean_lyric'] = lyrics['clean_lyric'].str.replace("?",'')

# Print the first five lines again to confirm correct changes.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                                    clean_lyric
# 0          he said the way my blue eyes shined
# 1  put those georgia stars to shame that night
# 2                           i said thats a lie
# 3                  just a boy in a chevy truck
# 4          that had a tendency of gettin stuck

# %%
# Create a list of "stop" words to remove.  These don't hold any value for our analysis.

stop = [
    'a', 'an', 'and', 'the', 'is', 'of', 'in', 'to', 'it', 'that', 'thats', 'this', 'was',
    'with', 'for', 'as', 'on', 'at', 'by', 'but', 'be', 'are', 'were', 'from',
    'or', 'if', 'not', 'have', 'has', 'had', 'who', 'which', 'am', 'being', 'been',
    'what', 'when', 'where', 'how', 'why', 'will', 'can', 'could', 'should', 'would',
    'there', 'then', 'those', 'here', 'there', 'put', 'said'
]


# Further clean our lyrics by removing stop words. 

# This function goes through all the words in our clean_lyric column.  If a word is not a stop word, add it to our
# final list of cleaned words.  Then, join all the words in the list back together into a single string, separated by
# a space.
def clean_lyric_text(text):
    words = text.split()
    cleaned_words = []
    for word in words:
        if word not in stop:
            cleaned_words.append(word)
    cleaned_text = ' '.join(cleaned_words)
    return cleaned_text


lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(clean_lyric_text)

# %%
# Inspect the first five rows to make sure the lyrics were correctly cleaned of stop words.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                   clean_lyric
# 0  he way my blue eyes shined
# 1   georgia stars shame night
# 2                       i lie
# 3        just boy chevy truck
# 4       tendency gettin stuck

# %% [markdown]
# # Searching for occurrences of certain words.

# %% [markdown]
# The newest album is called "Midnights".  It was released in 2022.  Let's see if the artist mentions midnight more often in it.

# %%
# Create a new column to reflect if the lyrics contain midnight

lyrics['midnight'] = lyrics['clean_lyric'].str.contains('midnight')

# Create a new dataframe grouped by album year, and count up the number of times the word 'midnight' 
# was mentioned in each one.
midnight_mentions = lyrics.groupby('album_year').sum().reset_index()

plt.plot(midnight_mentions['album_year'], midnight_mentions['midnight'])
plt.title("'midnight' mentions")
plt.show()

# %% [markdown]
# 'midnight' is mentioned far more on "Midnights" than any other album.

# %% [markdown]
# # Expanding the search

# %% [markdown]
# We see that there is a relationship between 'midnight' and its namesake album, but what will a plot look like for broader themes?

# %%
# Making lists of words that are categorically similar, to see if they are referenced in the songs.

night = ['night', 'midnight', 'dawn', 'dusk', 'evening', 'late', 'dark', '10pm', '11pm', '12am', '1am', '2am', '3am', '4am']
day = ['day', 'morning', 'light', 'sun', 'dawn', 'noon', 'golden', 'bright', '6am', '7am', '8am', '9am', '10am', '12pm']
time = ['today', 'tomorrow', 'yesterday', 'clock', 'hour', 'time', 'minute', 'second', 'past', 'present', 'future', 'moment']

# %%
# Regex pattern for each list to help with the searching.
night_regex = '|'.join(night)
day_regex = '|'.join(day)
time_regex = '|'.join(time)

# Creating a new column for each of the categories of words above, containing a boolean (either true or false) based on
# whether the lyrical line contains one of the words present in the lists.
lyrics['night'] = lyrics['clean_lyric'].str.contains(night_regex)
lyrics['day'] = lyrics['clean_lyric'].str.contains(day_regex)
lyrics['time'] = lyrics['clean_lyric'].str.contains(time_regex)

# Count the number of True values.
night_count = sum(lyrics['night'])
day_count = sum(lyrics['day'])
time_count = sum(lyrics['time'])

# Print the counts.
print("night words: ", night_count)
print("day words: ", day_count)
print("time words: ", time_count)
# Out:
# night words:  230
# day words:  288
# time words:  319

# %%
# Inspect the first 5 rows for intended output.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                   clean_lyric  midnight  night    day   time
# 0  he way my blue eyes shined     False  False  False  False
# 1   georgia stars shame night     False   True  False  False
# 2                       i lie     False  False  False  False
# 3        just boy chevy truck     False  False  False  False
# 4       tendency gettin stuck     False  False  False  False

# %% [markdown]
# 'time' has been referenced quite a bit, there's enough mentions to potentially spot some trends. Also, 'day' is mentioned more than 'night.'

# %% [markdown]
# # Visualizing change in mentions over time

# %%
# Create a new dataframe for yearly mentions, that group the occurrences of night, day, and time words by year.
yearly_mentions = lyrics.groupby('album_year').sum().reset_index()

yearly_mentions[['album_year', 'midnight', 'night', 'day', 'time']]
# Out:
#   album_year  midnight  night  day  time
# 0       2006         0     17   24    22
# 1       2008         0     21   19    25
# 2       2010         0     25   42    36
# 3       2012         1     41   40    66
# 4       2014         1     19   26    17
# 5       2017         3     25   25    35
# 6       2019         0     22   46    13
# 7       2020         1      8   17    47
# 8       2021         2     18   34    27
# 9       2022         9     34   15    31

# %%
# Plotting the mentions of 'night' over the years.

plt.plot(yearly_mentions['album_year'], yearly_mentions['night'])
plt.title("Night mentions")
plt.show()

# %% [markdown]
# "Midnights" (album), although not referencing night the most, does have a heavy night theme.  In fact, it is a theme that peaked in 2012. At which point, the artist began referencing it less and less over 8 years, before revisiting it in the last two albums.

# %% [markdown]
# # Most day and night centric albums

# %%
# Correcting the album names.

list_of_album_names = ["Taylor Swift", "Fearless", "Speak Now", "Red", "1989", "Reputation", "Lover", "Evermore", "Folklore", "Midnights"]

for i in range(10):
    yearly_mentions.at[i, 'album_name'] = list_of_album_names[i]

# %%
# Sort the lyrics by the night column to find the albums with the most references to 'night'.

yearly_mentions[['album_year', 'night', 'day', 'time', 'album_name']].sort_values(by = 'night', ascending = False)
# Out:
#   album_year  night  day  time    album_name
# 3       2012     41   40    66           Red
# 9       2022     34   15    31     Midnights
# 2       2010     25   42    36     Speak Now
# 5       2017     25   25    35    Reputation
# 6       2019     22   46    13         Lover
# 1       2008     21   19    25      Fearless
# 4       2014     19   26    17          1989
# 8       2021     18   34    27      Folklore
# 0       2006     17   24    22  Taylor Swift
# 7       2020      8   17    47      Evermore

# %%
# Sort the lyrics by the day column to find the albums with the most references to 'day'.

yearly_mentions[['album_year', 'night', 'day', 'time', 'album_name']].sort_values(by = 'day', ascending = False)
# Out:
#   album_year  night  day  time    album_name
# 6       2019     22   46    13         Lover
# 2       2010     25   42    36     Speak Now
# 3       2012     41   40    66           Red
# 8       2021     18   34    27      Folklore
# 4       2014     19   26    17          1989
# 5       2017     25   25    35    Reputation
# 0       2006     17   24    22  Taylor Swift
# 1       2008     21   19    25      Fearless
# 7       2020      8   17    47      Evermore
# 9       2022     34   15    31     Midnights

# %%
# Plotting the number of mentions of 'night' and 'day' through the years on the same graph 
# to help compare the two above tables.

plt.plot(yearly_mentions['album_year'], yearly_mentions['night'], label = 'night')
plt.plot(yearly_mentions['album_year'], yearly_mentions['day'], label = 'day')
plt.title("Day vs. Night mentions")

plt.legend()
plt.show()

# %% [markdown]
# # Investigating position of mentions within each album

# %% [markdown]
# Testing to see if there's any noticeable trend in the mentions throughout the course of the albums.  Will be plotting where within each album references to day and night occur.

# %%
# Creating a new column called "position" and assigning each lyrical line in the song a hash code based on its position in
# the album.  Example: All first lines of the first track in their album will share the same positional value.

lyrics['position'] = lyrics['track_n'] + (lyrics['line'] / 1000)

# Creating a new dataframe grouped by position.
positional_mentions = lyrics.groupby('position').sum().reset_index()

# The top line reads: Out of all the first lines in the discography, 1 of them references midnight, 2 of them reference night, 
# 2 of them reference day, and 2 of them reference time.
positional_mentions[['position', 'track_n', 'line', 'midnight', 'night', 'day', 'time']]
# Out:
#       position  track_n  line  midnight  night  day  time
# 0        1.001       10    10         1      2    2     2
# 1        1.002       10    20         0      1    0     0
# 2        1.003       10    30         0      0    1     0
# 3        1.004       10    40         0      1    1     0
# 4        1.005       10    50         0      0    1     0
# ...        ...      ...   ...       ...    ...  ...   ...
# 1208    18.055       18    55         0      0    0     0
# 1209    18.056       18    56         0      0    0     0
# 1210    18.057       18    57         0      1    0     0
# 1211    18.058       18    58         0      0    0     0
# 1212    18.059       18    59         0      0    0     0
#
# [1213 rows x 7 columns]

# %%
# Setting the size of the plot.
fig = plt.gcf()
fig.set_size_inches(20, 10)

# Creating a two-line plot with labels and lines to show frequency of 'night' and frequency of 'day'
# mentions.  The x axis is the positional value in the discography, and the 
plt.xlim(0, 20)
plt.ylim(0, 5)
plt.plot(positional_mentions['position'], positional_mentions['night'], label = 'night')
plt.plot(positional_mentions['position'], positional_mentions['day'], label = 'day')
plt.legend()
plt.title("Day vs. Night mentions by album position")

plt.show()

# %% [markdown]
# Experiment provides no meaningful results.

# %% [markdown]
# # Tokenizing the lyrics

# %%
# Tokenize the words in our clean_lyric column by splitting them around space characters.

lyrics['lyrics_tok'] = lyrics['clean_lyric'].str.split(' ')

# Inspect the first five lines so we can see what the new lyrics_token column looks like.

lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                   clean_lyric  midnight  night    day   time  position  \
# 0  he way my blue eyes shined     False  False  False  False     1.001
# 1   georgia stars shame night     False   True  False  False     1.002
# 2                       i lie     False  False  False  False     1.003
# 3        just boy chevy truck     False  False  False  False     1.004
# 4       tendency gettin stuck     False  False  False  False     1.005
#
#                           lyrics_tok
# 0  [he, way, my, blue, eyes, shined]
# 1     [georgia, stars, shame, night]
# 2                           [i, lie]
# 3          [just, boy, chevy, truck]
# 4          [tendency, gettin, stuck]

# %%
# Determine what the most frequently used words are by first creating a list of all the words
# in the lyrics_token column.

word_list = []

for list_of_words in lyrics['lyrics_tok']:
    for word in list_of_words:
        word_list.append(word)


# Utilize the counter function to count the number of times each word appears.
word_frequency = collections.Counter(word_list)

# Sort the word frequencies to determine the most common words used.  
# word_frequency.items() returns a tuple, and key is the element in the tuple to sort by. 
# The values are at index 1 of the tuple.
word_frequency = sorted(word_frequency.items(), key = lambda x: x[1], reverse = True)

# Display the word frequencies.
word_frequency
# Out:
# [('you', 2486),
#  ('i', 2411),
#  ('me', 940),
#  ('my', 804),
#  ('your', 574),
#  ('all', 483),
#  ('im', 483),
#  ('like', 458),
#  ('we', 441),
#  ('know', 409),
#  ('oh', 382),
#  ('its', 377),
#  ('so', 377),
#  ('dont', 330),
#  ('just', 325),
#  ('never', 317),
#  ('youre', 290),
#  ('now', 285),
#  ('love', 260),
#  ('up', 258),
#  ('time', 243),
#  ('cause', 223),
#  ('out', 218),
#  ('no', 198),
#  ('back', 194),
#  ('do', 193),
#  ('think', 185),
#  ('one', 185),
#  ('down', 180),
#  ('see', 177),
#  ('say', 174),
#  ('they', 174),
#  ('want', 161),
#  ('go', 151),
#  ('wanna', 150),
#  ('got', 149),
#  ('yeah', 148),
#  ('baby', 142),
#  ('ever', 140),
#  ('he', 134),
#  ('cant', 133),
#  ('get', 128),
#  ('right', 119),
#  ('ill', 116),
#  ('stay', 114),
#  ('did', 112),
#  ('still', 109),
#  ('look', 108),
#  ('take', 108),
#  ('gonna', 106),
#  ('id', 105),
#  ('tell', 103),
#  ('ive', 101),
#  ('made', 101),
#  ('off', 99),
#  ('ooh', 99),
#  ('night', 98),
#  ('good', 95),
#  ('about', 94),
#  ('too', 91),
#  ('bad', 89),
#  ('only', 89),
#  ('around', 87),
#  ('wish', 86),
#  ('better', 85),
#  ('again', 84),
#  ('call', 83),
#  ('oh-oh', 82),
#  ('our', 81),
#  ('shake', 81),
#  ('come', 79),
#  ('things', 79),
#  ('first', 77),
#  ('long', 76),
#  ('home', 76),
#  ('away', 76),
#  ('she', 76),
#  ('way', 75),
#  ('eyes', 75),
#  ('didnt', 75),
#  ('let', 73),
#  ('make', 73),
#  ('feel', 72),
#  ('new', 72),
#  ('yet', 71),
#  ('girl', 69),
#  ('everything', 68),
#  ('knew', 68),
#  ('last', 67),
#  ('through', 65),
#  ('break', 64),
#  ('youll', 62),
#  ('well', 62),
#  ('name', 62),
#  ('best', 60),
#  ('every', 60),
#  ('red', 60),
#  ('us', 59),
#  ('remember', 59),
#  ('nothing', 58),
#  ('even', 58),
#  ('something', 57),
#  ('him', 56),
#  ('heart', 55),
#  ('man', 55),
#  ('keep', 54),
#  ('mind', 54),
#  ('little', 53),
#  ('some', 53),
#  ('life', 53),
#  ('hey', 52),
#  ('friends', 51),
#  ('face', 51),
#  ('thought', 51),
#  ('isnt', 51),
#  ('gone', 50),
#  ('aint', 50),
#  ('thing', 49),
#  ('waiting', 49),
#  ('always', 49),
#  ('leave', 49),
#  ('beautiful', 48),
#  ('wanted', 48),
#  ('end', 48),
#  ('theres', 47),
#  ('car', 47),
#  ('into', 47),
#  ('forever', 47),
#  ('need', 46),
#  ('day', 46),
#  ('before', 46),
#  ('over', 46),
#  ('dancing', 46),
#  ('head', 45),
#  ('walk', 45),
#  ('whoa', 45),
#  ('mad', 45),
#  ('find', 44),
#  ('hope', 44),
#  ('mine', 44),
#  ('hes', 44),
#  ('hold', 44),
#  ('alone', 44),
#  ('hands', 44),
#  ('room', 44),
#  ('ah', 44),
#  ('hate', 43),
#  ('wont', 43),
#  ('whole', 43),
#  ('hand', 43),
#  ('nice', 42),
#  ('coming', 42),
#  ('them', 42),
#  ('meet', 42),
#  ('shes', 41),
#  ('her', 41),
#  ('clear', 41),
#  ('his', 40),
#  ('town', 40),
#  ('mean', 40),
#  ('once', 40),
#  ('daylight', 40),
#  ('dress', 39),
#  ('lights', 39),
#  ('saw', 38),
#  ('place', 38),
#  ('run', 38),
#  ('dreams', 38),
#  ('woods', 38),
#  ('sorry', 37),
#  ('smile', 37),
#  ('kiss', 37),
#  ('york', 37),
#  ('light', 36),
#  ('feeling', 36),
#  ('door', 36),
#  ('lost', 36),
#  ('gave', 36),
#  ('big', 36),
#  ('old', 35),
#  ('wrong', 35),
#  ('talk', 35),
#  ('street', 34),
#  ('live', 34),
#  ('enough', 34),
#  ('asking', 34),
#  ('much', 34),
#  ('ha', 34),
#  ('than', 33),
#  ('trying', 33),
#  ('play', 33),
#  ('miss', 33),
#  ('more', 32),
#  ('really', 32),
#  ('give', 32),
#  ('darling', 32),
#  ('trouble', 32),
#  ('used', 31),
#  ('known', 31),
#  ('met', 31),
#  ('took', 31),
#  ('welcome', 31),
#  ('blue', 30),
#  ('believe', 30),
#  ('world', 30),
#  ('shouldve', 30),
#  ('myself', 30),
#  ('these', 30),
#  ('game', 30),
#  ('|', 30),
#  ('watch', 29),
#  ('breathe', 29),
#  ('rain', 29),
#  ('their', 29),
#  ('yes', 29),
#  ('getting', 29),
#  ('lose', 29),
#  ('meaning', 29),
#  ('another', 28),
#  ('fight', 28),
#  ('anything', 28),
#  ('same', 28),
#  ('other', 28),
#  ('turn', 27),
#  ('times', 27),
#  ('might', 27),
#  ('together', 27),
#  ('soon', 27),
#  ('people', 27),
#  ('youve', 27),
#  ('hear', 27),
#  ('wait', 27),
#  ('touch', 27),
#  ('dark', 27),
#  ('official', 27),
#  ('lyrics', 27),
#  ('&', 27),
#  ('verified', 27),
#  ('fun', 27),
#  ('boy', 26),
#  ('song', 26),
#  ('hard', 26),
#  ('fake', 26),
#  ('try', 26),
#  ('late', 26),
#  ('til', 26),
#  ('real', 26),
#  ('else', 26),
#  ('loved', 26),
#  ('body', 26),
#  ('left', 25),
#  ('heard', 25),
#  ('goes', 25),
#  ('fall', 25),
#  ('story', 25),
#  ('honey', 25),
#  ('looking', 25),
#  ('seen', 25),
#  ('making', 25),
#  ('forget', 25),
#  ('friend', 25),
#  ('weve', 25),
#  ('places', 24),
#  ('high', 24),
#  ('falling', 24),
#  ('house', 24),
#  ('came', 24),
#  ('stop', 24),
#  ('help', 24),
#  ('joeboy', 24),
#  ('sip', 24),
#  ('alcohol', 24),
#  ('grow', 24),
#  ('lips', 24),
#  ('you’re', 24),
#  ('summer', 23),
#  ('crazy', 23),
#  ('drive', 23),
#  ('show', 23),
#  ('own', 23),
#  ('many', 23),
#  ('phone', 23),
#  ('dance', 23),
#  ('cool', 23),
#  ('please', 23),
#  ('pain', 23),
#  ('follow', 23),
#  ('blood', 23),
#  ('soul', 23),
#  ('karma', 23),
#  ('youd', 22),
#  ('ask', 22),
#  ('thinking', 22),
#  ('went', 22),
#  ('true', 22),
#  ('change', 22),
#  ('someone', 22),
#  ('wed', 22),
#  ('years', 22),
#  ('dead', 22),
#  ('sad', 22),
#  ('alright', 22),
#  ('starlight', 22),
#  ('getaway', 22),
#  ('since', 21),
#  ('looks', 21),
#  ('knows', 21),
#  ('kind', 21),
#  ('tied', 21),
#  ('days', 21),
#  ('snow', 21),
#  ('okay', 21),
#  ('comin', 21),
#  ('without', 20),
#  ('tonight', 20),
#  ('feels', 20),
#  ('nobody', 20),
#  ('after', 20),
#  ('side', 20),
#  ('ground', 20),
#  ('gotta', 20),
#  ('everybody', 20),
#  ('god', 19),
#  ('far', 19),
#  ('picture', 19),
#  ('fly', 19),
#  ('very', 19),
#  ('died', 19),
#  ('save', 19),
#  ('walked', 19),
#  ('deep', 19),
#  ('both', 19),
#  ('young', 19),
#  ('single', 19),
#  ('couldnt', 19),
#  ('line', 19),
#  ('running', 19),
#  ('read', 18),
#  ('road', 18),
#  ('cold', 18),
#  ('told', 18),
#  ('guess', 18),
#  ('hair', 18),
#  ('makes', 18),
#  ('city', 18),
#  ('sweet', 18),
#  ('games', 18),
#  ('someday', 17),
#  ('finally', 17),
#  ('found', 17),
#  ('sky', 17),
#  ('anymore', 17),
#  ('clean', 17),
#  ('wouldve', 17),
#  ('screaming', 17),
#  ('eye', 17),
#  ('because', 17),
#  ('string', 17),
#  ('babe', 17),
#  ('dream', 17),
#  ('loves', 17),
#  ('begin', 17),
#  ('works', 17),
#  ('beach', 17),
#  ('bet', 16),
#  ('lucky', 16),
#  ('maybe', 16),
#  ('whats', 16),
#  ('walking', 16),
#  ('stood', 16),
#  ('girls', 16),
#  ('does', 16),
#  ('gets', 16),
#  ('past', 16),
#  ('beat', 16),
#  ('almost', 16),
#  ('somebody', 16),
#  ('changed', 16),
#  ('standing', 16),
#  ('cut', 16),
#  ('alive', 16),
#  ('showed', 16),
#  ('yours', 16),
#  ('em', 16),
#  ('delicate', 16),
#  ('gorgeous', 16),
#  ('uh', 16),
#  ('cornelia', 16),
#  ('shame', 15),
#  ('favorite', 15),
#  ('happiness', 15),
#  ('fine', 15),
#  ('going', 15),
#  ('wishing', 15),
#  ('lot', 15),
#  ('couldve', 15),
#  ('doesnt', 15),
#  ('moment', 15),
#  ('bout', 15),
#  ('begging', 15),
#  ('wasnt', 15),
#  ('middle', 15),
#  ('easy', 15),
#  ('doing', 15),
#  ('sick', 15),
#  ('list', 15),
#  ('trust', 15),
#  ('shit', 15),
#  ('fancy', 15),
#  ('plans', 15),
#  ('bless', 15),
#  ('stars', 14),
#  ('bed', 14),
#  ('perfect', 14),
#  ('reason', 14),
#  ('anywhere', 14),
#  ('damn', 14),
#  ('window', 14),
#  ('taking', 14),
#  ('front', 14),
#  ('two', 14),
#  ('sometimes', 14),
#  ('while', 14),
#  ('theyre', 14),
#  ('ends', 14),
#  ('close', 14),
#  ('party', 14),
#  ('tired', 14),
#  ('wake', 14),
#  ('simple', 14),
#  ('hurt', 14),
#  ('doin', 14),
#  ('step', 14),
#  ('stand', 14),
#  ('nights', 14),
#  ('sun', 14),
#  ('under', 14),
#  ('worst', 14),
#  ('black', 13),
#  ('saying', 13),
#  ('says', 13),
#  ('words', 13),
#  ('wouldnt', 13),
#  ('pretty', 13),
#  ('looked', 13),
#  ('next', 13),
#  ('boys', 13),
#  ('wondering', 13),
#  ('white', 13),
#  ('magic', 13),
#  ('laughing', 13),
#  ('heres', 13),
#  ('rains', 13),
#  ('school', 13),
#  ('felt', 13),
#  ('december', 13),
#  ('floor', 13),
#  ('hit', 13),
#  ('drunk', 13),
#  ('quite', 13),
#  ('memories', 13),
#  ('don’t', 13),
#  ('free', 13),
#  ('kid', 13),
#  ('22', 13),
#  ('problems', 13),
#  ('bought', 13),
#  ('must', 13),
#  ('wine', 13),
#  ('ooh-ooh-ooh-ooh', 13),
#  ('burn', 12),
#  ('funny', 12),
#  ('anyone', 12),
#  ('paint', 12),
#  ('loving', 12),
#  ('outside', 12),
#  ('losing', 12),
#  ('golden', 12),
#  ('turned', 12),
#  ('morning', 12),
#  ('shine', 12),
#  ('behind', 12),
#  ('open', 12),
#  ('signs', 12),
#  ('sit', 12),
#  ('most', 12),
#  ('bright', 12),
#  ('speak', 12),
#  ('sure', 12),
#  ('gold', 12),
#  ('win', 12),
#  ('fell', 12),
#  ('rest', 12),
#  ('burned', 12),
#  ('burning', 12),
#  ('midnight', 12),
#  ('scene', 12),
#  ('hey!', 12),
#  ('theyll', 12),
#  ('pretend', 12),
#  ('usin', 12),
#  ('ooh-ah', 12),
#  ('takes', 11),
#  ('stupid', 11),
#  ('missing', 11),
#  ('though', 11),
#  ('ready', 11),
#  ('ending', 11),
#  ('walls', 11),
#  ('gray', 11),
#  ('goodbye', 11),
#  ('breath', 11),
#  ('stayed', 11),
#  ('along', 11),
#  ('hide', 11),
#  ('whenever', 11),
#  ('fire', 11),
#  ('apart', 11),
#  ('caught', 11),
#  ('fifteen', 11),
#  ('pulled', 11),
#  ('write', 11),
#  ('belong', 11),
#  ('killing', 11),
#  ('each', 11),
#  ('fighting', 11),
#  ('insane', 11),
#  ('wild', 11),
#  ('called', 11),
#  ('silence', 11),
#  ('sparks', 11),
#  ('die', 11),
#  ('passed', 11),
#  ('held', 11),
#  ('blind', 11),
#  ('blame', 11),
#  ('fast', 11),
#  ('broke', 11),
#  ('promise', 11),
#  ('flying', 11),
#  ('hell', 11),
#  ('cheeks', 11),
#  ('paper', 11),
#  ('marvelous', 11),
#  ('any', 11),
#  ('ya', 11),
#  ('style', 11),
#  ('sign', 11),
#  ('reputation', 11),
#  ('drug', 11),
#  ('forgot', 11),
#  ('woman', 11),
#  ('tears', 10),
#  ('three', 10),
#  ('whos', 10),
#  ('lying', 10),
#  ('sitting', 10),
#  ('revenge', 10),
#  ('laugh', 10),
#  ('wonder', 10),
#  ('perfectly', 10),
#  ('sleep', 10),
#  ('lets', 10),
#  ('until', 10),
#  ('undone', 10),
#  ('daydream', 10),
#  ('worth', 10),
#  ('tryna', 10),
#  ('invisible', 10),
#  ('inside', 10),
#  ('round', 10),
#  ('starts', 10),
#  ('comes', 10),
#  ('brought', 10),
#  ('figured', 10),
#  ('watched', 10),
#  ('scared', 10),
#  ('water', 10),
#  ('green', 10),
#  ('turns', 10),
#  ('peace', 10),
#  ('shaking', 10),
#  ('nobodys', 10),
#  ('started', 10),
#  ('lord', 10),
#  ('lover', 10),
#  ('money', 10),
#  ('weekend', 10),
#  ('wildest', 10),
#  ('worse', 10),
#  ('a-team', 10),
#  ('whys', 10),
#  ('american', 10),
#  ('kill', 10),
#  ('haze', 10),
#  ('worship', 10),
#  ('closure', 10),
#  ('shined', 9),
#  ('truck', 9),
#  ('heartbreak', 9),
#  ('strike', 9),
#  ('havent', 9),
#  ('taken', 9),
#  ('start', 9),
#  ('great', 9),
#  ('cried', 9),
#  ('less', 9),
#  ('work', 9),
#  ('pictures', 9),
#  ('sing', 9),
#  ('chance', 9),
#  ('crying', 9),
#  ('fearless', 9),
#  ('dancin', 9),
#  ('garden', 9),
#  ('mm-mm', 9),
#  ('leaving', 9),
#  ('lead', 9),
#  ('short', 9),
#  ('dreaming', 9),
#  ('2', 9),
#  ('heartbeat', 9),
#  ('push', 9),
#  ('rush', 9),
#  ('low', 9),
#  ('cuts', 9),
#  ('kitchen', 9),
#  ('pouring', 9),
#  ('swear', 9),
#  ('dressed', 9),
#  ('death', 9),
#  ('queen', 9),
#  ('everyone', 9),
#  ('bar', 9),
#  ('loud', 9),
#  ('lately', 9),
#  ('page', 9),
#  ('question', 9),
#  ('haunted', 9),
#  ('moved', 9),
#  ('uh-uh', 9),
#  ('months', 9),
#  ('king', 9),
#  ('covered', 9),
#  ('ra-di-di-di-di-di-di-di-di-di-da-da', 9),
#  ('champagne', 9),
#  ('rings', 9),
#  ('huh', 9),
#  ('tea', 9),
#  ('prove', 9),
#  ('goddamn', 9),
#  ('evermore', 9),
#  ('lavender', 9),
#  ('maroon', 9),
#  ('lie', 8),
#  ('jeans', 8),
#  ('letter', 8),
#  ('yourself', 8),
#  ('mess', 8),
#  ('seems', 8),
#  ('few', 8),
#  ('songs', 8),
#  ('leads', 8),
#  ('twice', 8),
#  ('word', 8),
#  ('instead', 8),
#  ('slow', 8),
#  ('half', 8),
#  ('living', 8),
#  ('scar', 8),
#  ('storm', 8),
#  ('hi', 8),
#  ('quiet', 8),
#  ('afraid', 8),
#  ('faith', 8),
#  ('talking', 8),
#  ('mmm', 8),
#  ('oh-oh-oh', 8),
#  ('small', 8),
#  ('happy', 8),
#  ('catch', 8),
#  ('wear', 8),
#  ('heels', 8),
#  ('none', 8),
#  ('innocent', 8),
#  ('hearts', 8),
#  ('mistakes', 8),
#  ('move', 8),
#  ('family', 8),
#  ('sleeping', 8),
#  ('flew', 8),
#  ('crowded', 8),
#  ('fate', 8),
#  ('howd', 8),
#  ('care', 8),
#  ('older', 8),
#  ('flames', 8),
#  ('broken', 8),
#  ('impossible', 8),
#  ('sound', 8),
#  ('pieces', 8),
#  ('cruel', 8),
#  ('ooh-ooh-ooh-ooh-ooh', 8),
#  ('oh-ho', 8),
#  ('warm', 8),
#  ('train', 8),
#  ('chasing', 8),
#  ('mmm-mmm', 8),
#  ('shiny', 8),
#  ('oh!', 8),
#  ('ha-ah', 8),
#  ('film', 8),
#  ('learned', 8),
#  ('calm', 8),
#  ('problem', 8),
#  ('warning', 8),
#  ('wreck', 8),
#  ('polish', 8),
#  ('dorothea', 8),
#  ('werent', 7),
#  ('standin', 7),
#  ('case', 7),
#  ('wearing', 7),
#  ('between', 7),
#  ('tried', 7),
#  ('lonely', 7),
#  ('mirror', 7),
#  ('cry', 7),
#  ('pay', 7),
#  ('conversation', 7),
#  ('forgiveness', 7),
#  ('wide', 7),
#  ('ran', 7),
#  ('believed', 7),
#  ('spot', 7),
#  ('ridin', 7),
#  ('hallway', 7),
#  ('stare', 7),
#  ('realized', 7),
#  ('flashback', 7),
#  ('scarlet', 7),
#  ('ring', 7),
#  ('mmm-mm', 7),
#  ('holding', 7),
#  ('arent', 7),
#  ('shoulda', 7),
#  ('feet', 7),
#  ('playing', 7),
#  ('someones', 7),
#  ('cursing', 7),
#  ('breaking', 7),
#  ('space', 7),
#  ('grew', 7),
#  ('it’s', 7),
#  ('hallelujah', 7),
#  ('throw', 7),
#  ('daughter', 7),
#  ('whisper', 7),
#  ('understand', 7),
#  ('dear', 7),
#  ('ones', 7),
#  ('dying', 7),
#  ('colder', 7),
#  ('spend', 7),
#  ('actress', 7),
#  ('roll', 7),
#  ('brand', 7),
#  ('kingdom', 7),
#  ('band', 7),
#  ('spinning', 7),
#  ('hurts', 7),
#  ('grace', 7),
#  ('wind', 7),
#  ('solve', 7),
#  ('treacherous', 7),
#  ('bone', 7),
#  ('drowning', 7),
#  ('telling', 7),
#  ('asked', 7),
#  ('hang', 7),
#  ('they’ll', 7),
#  ('rose', 7),
#  ('heaven', 7),
#  ('rumors', 7),
#  ('players', 7),
#  ('color', 7),
#  ('palm', 7),
#  ('whyd', 7),
#  ('mark', 7),
#  ('jump', 7),
#  ('thousand', 7),
#  ('london', 7),
#  ('me-e-e', 7),
#  ('tim', 6),
#  ('mcgraw', 6),
#  ('chest', 6),
#  ('faded', 6),
#  ('today', 6),
#  ('sunshine', 6),
#  ('given', 6),
#  ('use', 6),
#  ('shade', 6),
#  ('counting', 6),
#  ('scars', 6),
#  ('view', 6),
#  ('part', 6),
#  ('giving', 6),
#  ('least', 6),
#  ('fore', 6),
#  ('shouldnt', 6),
#  ('honestly', 6),
#  ('joke', 6),
#  ('screen', 6),
#  ('lovin', 6),
#  ('matter', 6),
#  ('secrets', 6),
#  ('fears', 6),
#  ('shell', 6),
#  ('wanting', 6),
#  ('driving', 6),
#  ('team', 6),
#  ('marry', 6),
#  ('la-la-la', 6),
#  ('crowd', 6),
#  ('hello', 6),
#  ('romeo', 6),
#  ('prince', 6),
#  ('pick', 6),
#  ('near', 6),
#  ('forth', 6),
#  ('itll', 6),
#  ('bring', 6),
#  ('2am', 6),
#  ('trees', 6),
#  ('names', 6),
#  ('ride', 6),
#  ('’cause', 6),
#  ('lives', 6),
#  ('learn', 6),
#  ('reckless', 6),
#  ('drop', 6),
#  ('haunt', 6),
#  ('arms', 6),
#  ('rules', 6),
#  ('pushed', 6),
#  ('clothes', 6),
#  ('grown', 6),
#  ('cross', 6),
#  ('enchanted', 6),
#  ('smoke', 6),
#  ('thinks', 6),
#  ('plane', 6),
#  ('pretenders', 6),
#  ('needed', 6),
#  ('top', 6),
#  ('tragic', 6),
#  ('tall', 6),
#  ('picked', 6),
#  ('ocean', 6),
#  ('lock', 6),
#  ('ex-lovers', 6),
#  ('crashing', 6),
#  ('t-shirt', 6),
#  ('twenty', 6),
#  ('windows', 6),
#  ('hung', 6),
#  ('done', 6),
#  ('frames', 6),
#  ('such', 6),
#  ('breeze', 6),
#  ('truth', 6),
#  ('da-da', 6),
#  ('chill', 6),
#  ('crime', 6),
#  ('me—', 6),
#  ('goes…', 6),
#  ('boyfriend', 6),
#  ('secret', 6),
#  ('shape', 6),
#  ('babys', 6),
#  ('above', 6),
#  ('dressing', 6),
#  ('midnights', 6),
#  ('become', 6),
#  ('existed', 6),
#  ('wants', 6),
#  ('1', 6),
#  ('except', 6),
#  ('hometown', 6),
#  ('likes', 6),
#  ('false', 6),
#  ('guy', 6),
#  ('august', 6),
#  ('bride', 6),
#  ('stone', 6),
#  ('agrees', 6),
#  ('karmas', 6),
#  ('mastermind', 6),
#  ('moon', 5),
#  ('beneath', 5),
#  ('radio', 5),
#  ('realize', 5),
#  ('match', 5),
#  ('wasted', 5),
#  ('drew', 5),
#  ('talks', 5),
#  ('tight', 5),
#  ('strong', 5),
#  ('rainy', 5),
#  ('waters', 5),
#  ('pocket', 5),
#  ('price', 5),
#  ('smiles', 5),
#  ('na', 5),
#  ('yesterday', 5),
#  ('bigger', 5),
#  ('seat', 5),
#  ('nothin', 5),
#  ('notice', 5),
#  ('listen', 5),
#  ('drag', 5),
#  ('brave', 5),
#  ('air', 5),
#  ('princess', 5),
#  ('stephen', 5),
#  ('tossing', 5),
#  ('angel', 5),
#  ('reasons', 5),
#  ('knees', 5),
#  ('music', 5),
#  ('understands', 5),
#  ('tragedy', 5),
#  ('swing', 5),
#  ('attitude', 5),
#  ('comfortable', 5),
#  ('ships', 5),
#  ('history', 5),
#  ('faster', 5),
#  ('lasts', 5),
#  ('careless', 5),
#  ('mans', 5),
#  ('careful', 5),
#  ('forward', 5),
#  ('full', 5),
#  ('kinda', 5),
#  ('sidewalk', 5),
#  ('weather', 5),
#  ('pride', 5),
#  ('church', 5),
#  ('vow', 5),
#  ('messed', 5),
#  ('twisted', 5),
#  ('shining', 5),
#  ('voice', 5),
#  ('lies', 5),
#  ('nothings', 5),
#  ('dropped', 5),
#  ('wonderstruck', 5),
#  ('stealing', 5),
#  ('saint', 5),
#  ('war', 5),
#  ('crowds', 5),
#  ('kings', 5),
#  ('queens', 5),
#  ('i’ll', 5),
#  ('colors', 5),
#  ('slope', 5),
#  ('i-i-i', 5),
#  ('headlights', 5),
#  ('ago', 5),
#  ('stories', 5),
#  ('across', 5),
#  ('hanging', 5),
#  ('i’m', 5),
#  ('fit', 5),
#  ('affair', 5),
#  ('different', 5),
#  ('fame', 5),
#  ('diamonds', 5),
#  ('splashed', 5),
#  ('land', 5),
#  ('painted', 5),
#  ('highest', 5),
#  ('james', 5),
#  ('guys', 5),
#  ('skies', 5),
#  ('moves', 5),
#  ('straight', 5),
#  ('starin', 5),
#  ('sunset', 5),
#  ('ghost', 5),
#  ('screams', 5),
#  ('i-i', 5),
#  ('sight', 5),
#  ('track', 5),
#  ('trace', 5),
#  ('island', 5),
#  ('reputations', 5),
#  ('drama', 5),
#  ('ivy', 5),
#  ...]

# %% [markdown]
# 7 of the top 9 used words are references to "you" and "me".  The artist is writing about the relationship between two people (themselves and someone else.)

# %% [markdown]
# # Analyzing lyric sentiment

# %%
# Adding an NLTK package for our sentiment analyzer.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\rlawt\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Testing out the sentiment analyzer on sample text.
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love Taylor Swift!")
# Out:
# {'neg': 0.0, 'neu': 0.137, 'pos': 0.863, 'compound': 0.7424}

# %% [markdown]
# Compound is a composite score that summarizes the overall sentiment of the string. A score closer to 1 indicates a positive sentiment, a score closer to -1 indicates a negative sentiment, and 0 is neutral.  It is created using a weighted average of the scores for pos, neg, and neu.  So the scores for each word are combined, taking into account intensity and position of the word.  This first computation results in an intermediate score.  The final compound score is computed as a weighted average of this intermediate score, the 'pos' (positive) score, the 'neg' (negative) score, and the 'neu' (neutral) score.

# %%
# This particular analyzer takes in an entire string and applies its own tokenization process to it (per its documentation.)  
# Therefore, I don't want to use already tokenized lyrics.

# Apply sentiment analyzer's polarity_scores() function to everything in the clean_lyric column.
# Returns a dictionary to be stored in our new column containing values for 'negative', 'neutral', 'positive'.
lyrics['polarity'] = lyrics['clean_lyric'].apply(lambda x: sia.polarity_scores(x))

# Inspect the first five rows of the dataframe.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                   clean_lyric  midnight  night    day   time  position  \
# 0  he way my blue eyes shined     False  False  False  False     1.001
# 1   georgia stars shame night     False   True  False  False     1.002
# 2                       i lie     False  False  False  False     1.003
# 3        just boy chevy truck     False  False  False  False     1.004
# 4       tendency gettin stuck     False  False  False  False     1.005
#
#                           lyrics_tok  \
# 0  [he, way, my, blue, eyes, shined]
# 1     [georgia, stars, shame, night]
# 2                           [i, lie]
# 3          [just, boy, chevy, truck]
# 4          [tendency, gettin, stuck]
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.508, 'neu': 0.492, 'pos': 0.0, 'comp...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound...

# %%
# Transform the column with the polarity dictionaries into new, separate columns for each value using pandas series.
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)

# Drop the polarity column because A) we no longer need it, and B) we won't be able to sum the dataframe anymore 
# with it in it.
lyrics = lyrics.drop('polarity', axis = 1)

# %%
# Inspect first five rows to see the newly created columns.
lyrics.head()
# Out:
#      album_name track_title  track_n  \
# 0  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line album_year  \
# 0          He said the way my blue eyes shined     1       2006
# 1  Put those Georgia stars to shame that night     2       2006
# 2                       I said, "That's a lie"     3       2006
# 3                  Just a boy in a Chevy truck     4       2006
# 4         That had a tendency of gettin' stuck     5       2006
#
#                   clean_lyric  midnight  night    day   time  position  \
# 0  he way my blue eyes shined     False  False  False  False     1.001
# 1   georgia stars shame night     False   True  False  False     1.002
# 2                       i lie     False  False  False  False     1.003
# 3        just boy chevy truck     False  False  False  False     1.004
# 4       tendency gettin stuck     False  False  False  False     1.005
#
#                           lyrics_tok    neg    neu  pos  compound
# 0  [he, way, my, blue, eyes, shined]  0.000  1.000  0.0    0.0000
# 1     [georgia, stars, shame, night]  0.508  0.492  0.0   -0.4767
# 2                           [i, lie]  0.000  1.000  0.0    0.0000
# 3          [just, boy, chevy, truck]  0.000  1.000  0.0    0.0000
# 4          [tendency, gettin, stuck]  0.500  0.500  0.0   -0.2500

# %%
# Calculate the total (overall) postivity, negativity and compound score for our lyrics dataframe.
pos = sum(lyrics['pos'])
neg = sum(lyrics['neg'])
compound = sum(lyrics['compound'])

# Print the sums.
print("positive: ", pos)
print("negative: ", neg)
print("compound: ", compound)
# Out:
# positive:  1146.1499999999985
# negative:  758.4700000000013
# compound:  380.8444000000003

# %% [markdown]
# Overall, the artist's lyrics are mostly positive.

# %%
# Create a new DataFrame using the groupby method for the album_year
yearly_sentiment = lyrics.groupby('album_year').sum().reset_index()

# Plot the change in sentiment over time.
plt.plot(yearly_sentiment['album_year'], yearly_sentiment['compound'], label = 'compound')
plt.legend()
plt.title("Change in sentiment over time")
plt.show()

# %% [markdown]
# Since none of the values plotted are in the negative, that means the overall sentiment of each of the albums is positive - though you can see that 2 of the albums creeped closed to being neutral.  Also, the positivity fluctuates every 2 albums or so.  And surprisingly, the most recent album, "Midnights," is on par with being one of the more positive albums - despite heavily referencing night and darkness.

# %% [markdown]
# # Positivity/Negativity of 'night' and 'day'

# %%
# Create a dataframe filtered for only night mentions (contains only the lines that reference night.)
night = lyrics[lyrics['night'] == True]

# Do the same for day mentions.
day = lyrics[lyrics['day'] == True]

# Check the length of the night and day dataframes to make sure it is the number we saw earlier.
print("night: ", len(night))
print("day: ", len(day))
# Out:
# night:  230
# day:  288

# %%
# Take the dataframes that have been filtered for night and day and sum their compound column.
night_sentiment = night['compound'].sum()
day_sentiment = day['compound'].sum()

# Print the sentiment compounds.
print("night sentiment: ", night_sentiment)
print("day sentiment: ", day_sentiment)
# Out:
# night sentiment:  14.4254
# day sentiment:  18.665100000000002

# %% [markdown]
# Despite perhaps having a negative, or at least a sad/depressive connotation, 'night' actually holds a positive sentiment value.  This explains why a night-centric album like "Midnights" can also be one of the more positive albums.
